# %%
import pandas as pd

# %%
s =pd.Series([10,77,12,4,5])
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index  #indexler kaçtan başlayıp kaçta bitiyor kaçar kaçar artıyor
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
s.dtype #içeriğin bilgisini verir
# Out:
# dtype('O')

# %%
s.size #kaç eleman olduğunu verir
s.ndim #kaç boyutlu olduğunu verir
s.values #içeriği verir,
type(s.values)
# Out:
# array([10, 77, 12, 4, 5, 's'], dtype=object)

# %%
s.head(2) #ilk iki elemanı verir
s.tail(2) #son iki elemanı verir

# %% [markdown]
# Read csv

# %%
df=pd.read_csv("advertising.csv")

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset("titanic")
df.head()
df.tail()
df.shape
df.info()
df.columns
df.index
df.describe().T
df.isnull().values.any()
df.isnull().sum()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df['sex'].head()
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df[0:13] #0 dahil 13 dahil değil
df.drop(0,axis=0).head()#sıfır indexini siler
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0          0       3    male  22.0      1      0   7.2500        S   Third
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 3          1       1  female  35.0      1      0  53.1000        S   First
# 4          0       3    male  35.0      0      0   8.0500        S   Third
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 6          0       1    male  54.0      0      0  51.8625        S   First
# 7          0       3    male   2.0      3      1  21.0750        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# ...

# %%
#df["age"].head()
#df.age.head()

df.index = df["age"]
#df.drop("age",axis=1,inplace=True) ###inplace=True aksiyonu kalıcı yapar
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-a7627f31468e> in <cell line: 2>()
#       1 #df["age"].head()
# ----> 2 df.age.head()
#       3
#       4 df.index = df["age"]
#       5 df.drop("age",axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'age'

# %%
df["Age"]=df.index

# %%
df =df.reset_index()
df.head()
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
# 3      3  35.0         1       1  female      1      0  53.1000        S
# 4      4  35.0         0       3    male      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone   Age
# 0  Third    man        True  NaN  Southampton    no  False  22.0
# 1  First  woman       False    C    Cherbourg   yes  False  38.0
# 2  Third  woman       False  NaN  Southampton   yes   True  26.0
# 3  First  woman       False    C  Southampton   yes  False  35.0
# 4  Third    man        True  NaN  Southampton    no   True  35.0

# %%
pd.set_option("display.max_columns",None)
df
# Out:
#      index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0        0  22.0         0       3    male      1      0   7.2500        S
# 1        1  38.0         1       1  female      1      0  71.2833        C
# 2        2  26.0         1       3  female      0      0   7.9250        S
# 3        3  35.0         1       1  female      1      0  53.1000        S
# 4        4  35.0         0       3    male      0      0   8.0500        S
# ..     ...   ...       ...     ...     ...    ...    ...      ...      ...
# 886    886  27.0         0       2    male      0      0  13.0000        S
# 887    887  19.0         1       1  female      0      0  30.0000        S
# 888    888   NaN         0       3  female      1      2  23.4500        S
# 889    889  26.0         1       1    male      0      0  30.0000        C
# 890    890  32.0         0       3    male      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone   Age
# ...

# %%
df[["Age"]].head()
type(df[["Age"]].head()) #dataframe döndü
# Out:
# pandas.core.frame.DataFrame

# %%
df["Age"].head()
type(df["Age"].head()) #series döndü
# Out:
# pandas.core.series.Series

# %%
df["Age2"]=df["Age"]*2
df.head()

df["Age3"]=df["Age"]/df["Age2"]
df.head()
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
# 3      3  35.0         1       1  female      1      0  53.1000        S
# 4      4  35.0         0       3    male      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone   Age  Age2  Age3
# 0  Third    man        True  NaN  Southampton    no  False  22.0  44.0   0.5
# 1  First  woman       False    C    Cherbourg   yes  False  38.0  76.0   0.5
# 2  Third  woman       False  NaN  Southampton   yes   True  26.0  52.0   0.5
# 3  First  woman       False    C  Southampton   yes  False  35.0  70.0   0.5
# 4  Third    man        True  NaN  Southampton    no   True  35.0  70.0   0.5

# %%
df.drop(["Age3","Age2"],axis=1,inplace=True)
df.head()
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
# 3      3  35.0         1       1  female      1      0  53.1000        S
# 4      4  35.0         0       3    male      0      0   8.0500        S
#
#    class    who  adult_male deck  embark_town alive  alone   Age
# 0  Third    man        True  NaN  Southampton    no  False  22.0
# 1  First  woman       False    C    Cherbourg   yes  False  38.0
# 2  Third  woman       False  NaN  Southampton   yes   True  26.0
# 3  First  woman       False    C  Southampton   yes  False  35.0
# 4  Third    man        True  NaN  Southampton    no   True  35.0

# %%
df.drop("Age",axis=1,inplace=True)

# %%
df.loc[:, ~df.columns.str.contains("age")].head()
# Out:
#    index  survived  pclass     sex  sibsp  parch     fare embarked  class  \
# 0      0         0       3    male      1      0   7.2500        S  Third
# 1      1         1       1  female      1      0  71.2833        C  First
# 2      2         1       3  female      0      0   7.9250        S  Third
# 3      3         1       1  female      1      0  53.1000        S  First
# 4      4         0       3    male      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.iloc[:3]
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True

# %%
df.loc[:3]
# Out:
#    index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 0      0  22.0         0       3    male      1      0   7.2500        S
# 1      1  38.0         1       1  female      1      0  71.2833        C
# 2      2  26.0         1       3  female      0      0   7.9250        S
# 3      3  35.0         1       1  female      1      0  53.1000        S
#
#    class    who  adult_male deck  embark_town alive  alone
# 0  Third    man        True  NaN  Southampton    no  False
# 1  First  woman       False    C    Cherbourg   yes  False
# 2  Third  woman       False  NaN  Southampton   yes   True
# 3  First  woman       False    C  Southampton   yes  False

# %%
df.iloc[1,1]
# Out:
# 38.0

# %%
df[df["age"]>50].head()
# Out:
#     index   age  survived  pclass     sex  sibsp  parch     fare embarked  \
# 6       6  54.0         0       1    male      0      0  51.8625        S
# 11     11  58.0         1       1  female      0      0  26.5500        S
# 15     15  55.0         1       2  female      0      0  16.0000        S
# 33     33  66.0         0       2    male      0      0  10.5000        S
# 54     54  65.0         0       1    male      0      1  61.9792        C
#
#      class    who  adult_male deck  embark_town alive  alone
# 6    First    man        True    E  Southampton    no   True
# 11   First  woman       False    C  Southampton   yes   True
# 15  Second  woman       False  NaN  Southampton   yes   True
# 33  Second    man        True  NaN  Southampton    no   True
# 54   First    man        True    B    Cherbourg    no  False

# %%
df[df["age"]>50]["age"].count()
# Out:
# 64

# %%
df_new=df.loc[(df["age"]>5)
  & (df["sex"]=="male")
  & ((df["embark_town"]=="Cherbourg") |(df["embark_town"]=="Southampton" ))
  ,["age","class","embark_town"]]

df_new["embark_town"].value_counts()
# Out:
# embark_town
# Southampton    349
# Cherbourg       67
# Name: count, dtype: int64

# %%
df.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
df.groupby("sex").agg({"age":["mean","sum"]})
# Out:
#               age
#              mean       sum
# sex
# female  27.915709   7286.00
# male    30.726645  13919.17

# %%
df.groupby("sex").agg({"age":["mean","sum"],
                    "embark_town":"count"   })
# Out:
#               age           embark_town
#              mean       sum       count
# sex
# female  27.915709   7286.00         312
# male    30.726645  13919.17         577

# %%
df.groupby(["sex","embark_town","class"]).agg({
    "age":["mean","sum"],
    "survived":"mean",
    "sex":"count"
    })
# Out:
# <ipython-input-81-6a5a8d5c695e>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby(["sex","embark_town","class"]).agg({
#                                  age           survived   sex
#                                 mean      sum      mean count
# sex    embark_town class
# female Cherbourg   First   36.052632  1370.00  0.976744    43
#                    Second  19.142857   134.00  1.000000     7
#                    Third   14.062500   225.00  0.652174    23
#        Queenstown  First   33.000000    33.00  1.000000     1
#                    Second  30.000000    30.00  1.000000     2
#                    Third   22.850000   228.50  0.727273    33
#        Southampton First   32.704545  1439.00  0.958333    48
#                    Second  29.719697  1961.50  0.910448    67
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
pd.set_option("display.max_columns",None)
df=sns.load_dataset("titanic")
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.pivot_table("survived","sex","embarked")
# Out:
# embarked         C         Q         S
# sex
# female    0.876712  0.750000  0.689655
# male      0.305263  0.073171  0.174603

# %%
df.pivot_table("survived","sex",["embarked","class"])
# Out:
# embarked         C                      Q                          S  \
# class        First Second     Third First Second     Third     First
# sex
# female    0.976744    1.0  0.652174   1.0    1.0  0.727273  0.958333
# male      0.404762    0.2  0.232558   0.0    0.0  0.076923  0.354430
#
# embarked
# class       Second     Third
# sex
# female    0.910448  0.375000
# male      0.154639  0.128302

# %%
df["new_age"]=pd.cut(df["age"],[0,10,18,25,40,90])

# %%
df.pivot_table("survived","sex","new_age")
# Out:
# new_age   (0, 10]  (10, 18]  (18, 25]  (25, 40]  (40, 90]
# sex
# female   0.612903  0.729730  0.759259  0.802198  0.770833
# male     0.575758  0.131579  0.120370  0.220930  0.176471

# %%
df.pivot_table("survived","sex",["new_age","class"])
# Out:
# new_age (0, 10]                   (10, 18]                   (18, 25]  \
# class     First Second     Third     First Second     Third     First
# sex
# female      0.0    1.0  0.500000  1.000000    1.0  0.523810  0.941176
# male        1.0    1.0  0.363636  0.666667    0.0  0.103448  0.333333
#
# new_age                      (25, 40]                      (40, 90]            \
# class      Second     Third     First    Second     Third     First    Second
# sex
# female   0.933333  0.500000  1.000000  0.906250  0.464286  0.961538  0.846154
# male     0.047619  0.115385  0.513514  0.071429  0.172043  0.280000  0.095238
#
# new_age
# class       Third
# sex
# female   0.111111
# male     0.064516

# %% [markdown]
# **Apply & Lambda**

# %%
df["age2"]=df["age"]*2
df["age3"]=df["age"]**2

#df.drop("new_age",axis=1,inplace=True)
for col in df.columns:
  if "age" in col:
    df[col] = df[col]/10

# %%
df[["age","age2","age3"]].apply(lambda x:x/10).head()
# Out:
#     age  age2   age3
# 0  0.22  0.44   4.84
# 1  0.38  0.76  14.44
# 2  0.26  0.52   6.76
# 3  0.35  0.70  12.25
# 4  0.35  0.70  12.25

# %%
import pandas as pd
import seaborn as sns
import numpy as np
m = np.random.randint(1,30, size = (5,3))
df1 = pd.DataFrame(m, columns = ["var1", "var2", "var3"])
df2 = df1 + 99
pd.concat([df1, df2],ignore_index=True)
# Out:
#    var1  var2  var3
# 0    15     7    28
# 1     9     5     8
# 2    16    10    14
# 3    26     7     1
# 4    11     7    21
# 5   114   106   127
# 6   108   104   107
# 7   115   109   113
# 8   125   106   100
# 9   110   106   120

# %%
df1=pd.DataFrame({"employees":["john","dennis","mark","maria"],
                  "group": ["accounting","engineering","engineering","hr"]})

df2=pd.DataFrame({"employees":["john","dennis","mark","maria"],
                  "start_date":[2010,2009,2014,2019]})

pd.merge(df1,df2)
# Out:
#   employees        group  start_date
# 0      john   accounting        2010
# 1    dennis  engineering        2009
# 2      mark  engineering        2014
# 3     maria           hr        2019
