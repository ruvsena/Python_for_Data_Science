# %%
import numpy as np
import pandas as pd

df =pd.read_csv("/content/persona.csv")
df.head()
# Out:
#    PRICE   SOURCE   SEX COUNTRY  AGE
# 0     39  android  male     bra   17
# 1     39  android  male     bra   17
# 2     49  android  male     bra   17
# 3     29  android  male     tur   17
# 4     49  android  male     tur   17

# %%
df['SOURCE'].unique().sum()
# Out:
# 'androidios'

# %%
df['SOURCE'].value_counts()
# Out:
# SOURCE
# android    2974
# ios        2026
# Name: count, dtype: int64

# %%
df['PRICE'].unique().sum()
# Out:
# 204

# %%
df['PRICE'].value_counts()
# Out:
# PRICE
# 29    1305
# 39    1260
# 49    1031
# 19     992
# 59     212
# 9      200
# Name: count, dtype: int64

# %%
df['COUNTRY'].value_counts()
# Out:
# COUNTRY
# usa    2065
# bra    1496
# deu     455
# tur     451
# fra     303
# can     230
# Name: count, dtype: int64

# %%
df.groupby('COUNTRY')['PRICE'].sum()
df.groupby("COUNTRY").agg({"PRICE":"sum"})
# Out:
#          PRICE
# COUNTRY
# bra      51354
# can       7730
# deu      15485
# fra      10177
# tur      15689
# usa      70225

# %%
df["SOURCE"].value_counts()
# Out:
# SOURCE
# android    2974
# ios        2026
# Name: count, dtype: int64

# %%
df.groupby("COUNTRY").agg({"PRICE":"mean"})
# Out:
#              PRICE
# COUNTRY
# bra      34.327540
# can      33.608696
# deu      34.032967
# fra      33.587459
# tur      34.787140
# usa      34.007264

# %%
df.groupby("SOURCE").agg({"PRICE":"mean"})
# Out:
#              PRICE
# SOURCE
# android  34.174849
# ios      34.069102

# %%
df.groupby(["COUNTRY","SOURCE"]).agg({"PRICE":"mean"})
# Out:
#                      PRICE
# COUNTRY SOURCE
# bra     android  34.387029
#         ios      34.222222
# can     android  33.330709
#         ios      33.951456
# deu     android  33.869888
#         ios      34.268817
# fra     android  34.312500
#         ios      32.776224
# tur     android  36.229437
#         ios      33.272727
# usa     android  33.760357
#         ios      34.371703

# %%
agg_df=df.groupby(["COUNTRY","SOURCE","SEX","AGE"]).agg({"PRICE":"mean"}).sort_values("PRICE",ascending=False)

# %%
agg_df.reset_index(inplace=True)

# %%
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE
# 0     bra  android    male   46   59.0
# 1     usa  android    male   36   59.0
# 2     fra  android  female   24   59.0
# 3     usa      ios    male   32   54.0
# 4     deu  android  female   36   49.0

# %%
age=[0,18,23,30,40,70]
age_labels=["0_18","19_23","24_30","31_40","41_70"]

agg_df["AGE_CAT"] = pd.cut(agg_df["AGE"], age, labels=age_labels)

agg_df.head(10).to_excel("eb_score.xlsx", index=False)

# %%
agg_df["customers_level_based"] =agg_df[["COUNTRY","SOURCE","SEX","AGE_CAT"]].agg(lambda x: '_'.join(x).upper(), axis=1)

# %%
agg_df.head()
# Out:
#   COUNTRY   SOURCE     SEX  AGE  PRICE AGE_CAT     customers_level_based
# 0     bra  android    male   46   59.0   41_70    BRA_ANDROID_MALE_41_70
# 1     usa  android    male   36   59.0   31_40    USA_ANDROID_MALE_31_40
# 2     fra  android  female   24   59.0   24_30  FRA_ANDROID_FEMALE_24_30
# 3     usa      ios    male   32   54.0   31_40        USA_IOS_MALE_31_40
# 4     deu  android  female   36   49.0   31_40  DEU_ANDROID_FEMALE_31_40

# %%
agg_df["SEGMENT"]=pd.qcut(agg_df["PRICE"],4,labels=["D","C","B","A"])
agg_df.head(30)
agg_df.groupby("SEGMENT").agg({"PRICE":["mean","max","sum"]})
# Out:
# <ipython-input-37-d9bc53c677d2>:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   agg_df.groupby("SEGMENT").agg({"PRICE":["mean","max","sum"]})
#              PRICE
#               mean        max          sum
# SEGMENT
# D        27.302596  31.105263  2375.325850
# C        32.933339  34.000000  3128.667165
# B        35.436170  37.000000  2870.329792
# A        41.434736  59.000000  3521.952577

# %%
new_user="TUR_ANDROID_FEMALE_31_40"
agg_df[agg_df["customers_level_based"]==new_user]
# Out:
#    COUNTRY   SOURCE     SEX  AGE      PRICE AGE_CAT     customers_level_based  \
# 18     tur  android  female   32  43.000000   31_40  TUR_ANDROID_FEMALE_31_40
# 35     tur  android  female   31  40.666667   31_40  TUR_ANDROID_FEMALE_31_40
#
#    SEGMENT
# 18       A
# 35       A

# %%
new_user="FRA_IOS_FEMALE_31_40"
agg_df[agg_df["customers_level_based"]==new_user]
# Out:
#     COUNTRY SOURCE     SEX  AGE      PRICE AGE_CAT customers_level_based  \
# 208     fra    ios  female   40  33.000000   31_40  FRA_IOS_FEMALE_31_40
# 221     fra    ios  female   31  32.636364   31_40  FRA_IOS_FEMALE_31_40
#
#     SEGMENT
# 208       C
# 221       C
